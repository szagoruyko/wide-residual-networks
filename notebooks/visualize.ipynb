# %%
import pandas as pd
import json
from bokeh.plotting import figure, output_notebook, show
import numpy as np
from bokeh.charts.utils import cycle_colors
import sweeper

output_notebook()
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3a4f74d8-9509-492c-8f77-132a5048960a">Loading BokehJS ...</span>
#     </div>

# %%
from IPython.display import display

def plotLogs(log_names):
    # parse log files, extracting json entry with stats per epoch and creating pandas DataFrame
    frames = [pd.DataFrame(sweeper.loadLog('../pytorch/logs/'+log+'/log.txt')) for log in log_names]
    colors = ['red','blue','green','black','purple','orange','yellow']
    
    # this searches constant parameters across different runs to generate legends
    legends = sweeper.generateLegends(frames)

    # TODO: improve this, add hovers etc.
    p = figure(title='test error', x_axis_label='epoch')
    for i,frame in enumerate(frames):
        p.line(frame['epoch'], 100-frame['test_acc'], color=colors[i], legend=legends[i])
    show(p)
    
    p = figure(title='train_loss', x_axis_label='epoch', y_axis_label='loss')
    for i,frame in enumerate(frames):
        p.line(frame['epoch'], np.log(frame['train_loss']), color=colors[i], legend=legends[i])
    show(p)

# %%
plotLogs([
    'resnet_baseline'
])
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f6e2c6e1-db22-4f15-b17c-bbc2f38d3ac3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f6e2c6e1-db22-4f15-b17c-bbc2f38d3ac3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f6e2c6e1-db22-4f15-b17c-bbc2f38d3ac3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"156ccd8c-d082-436f-848f-d58e05853c76":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"89427760-b540-4bbf-a885-331b233e8827","type":"Line"},{"attributes":{},"id":"aaa5de19-89f7-4eac-aa17-b44962953249","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"8f79a827-a1ab-4ebb-b397-d6d849719ed5","subtype":"Figure","type":"Plot"},"ticker":{"id":"1aee9e3c-abc6-4bb1-b5d9-dbe7479e36f5","type":"BasicTicker"}},"id":"31fc2f12-edb6-4081-ab6d-5c011e10bc59","type":"Grid"},{"attributes":{},"id":"4401a2c4-d520-4f52-a4c6-796b1726ae8d","type":"BasicTicker"},{"attributes":{"callback":null},"id":"4bfda0e0-6449-4d69-a78b-5ee9f1437c10","type":"DataRange1d"},{"attributes":{"plot":{"id":"8f79a827-a1ab-4ebb-b397-d6d849719ed5","subtype":"Figure","type":"Plot"}},"id":"53534e65-3fbf-47ec-a4c4-66f85b327af3","type":"HelpTool"},{"attributes":{"plot":{"id":"8f79a827-a1ab-4ebb-b397-d6d849719ed5","subtype":"Figure","type":"Plot"}},"id":"8dfabf22-368f-4a85-a441-0134b08224a0","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,2,3,4,5,6,7,8],"y":[49.93000000000001,39.7,39.21,40.53,25.849999999999994,27.97,26.120000000000005,32.5]}},"id":"1c4bd289-bced-48ae-aca1-bf661b0ed325","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b49bc816-94fc-4af5-9864-cb980e7d8806","type":"PanTool"},{"id":"9843e058-81c5-41c2-b5a0-5a4cf097f42a","type":"WheelZoomTool"},{"id":"3529619b-7ea4-434e-afb7-e1c5348cff75","type":"BoxZoomTool"},{"id":"8dfabf22-368f-4a85-a441-0134b08224a0","type":"SaveTool"},{"id":"0162bf94-53d6-450a-8991-1cdc165f4618","type":"ResetTool"},{"id":"53534e65-3fbf-47ec-a4c4-66f85b327af3","type":"HelpTool"}]},"id":"df4c9ad0-e59f-453a-b6d8-011d0af9de90","type":"Toolbar"},{"attributes":{"formatter":{"id":"63b61bca-548e-4e3c-b7c5-30c974cf42de","type":"BasicTickFormatter"},"plot":{"id":"8f79a827-a1ab-4ebb-b397-d6d849719ed5","subtype":"Figure","type":"Plot"},"ticker":{"id":"1aee9e3c-abc6-4bb1-b5d9-dbe7479e36f5","type":"BasicTicker"}},"id":"2ff4d719-62c3-4ccd-bc1f-4c999f3d2971","type":"LinearAxis"},{"attributes":{"plot":null,"text":"test error"},"id":"a00f20f3-8313-41e8-ad00-0c7688a41942","type":"Title"},{"attributes":{"callback":null},"id":"b04a5cc2-875d-4ac8-af24-d4fe77ed3e3d","type":"DataRange1d"},{"attributes":{"plot":{"id":"8f79a827-a1ab-4ebb-b397-d6d849719ed5","subtype":"Figure","type":"Plot"},"ticker":{"id":"4401a2c4-d520-4f52-a4c6-796b1726ae8d","type":"BasicTicker"}},"id":"c4625a19-a72d-417d-94d3-b6afb0ee15b0","type":"Grid"},{"attributes":{"data_source":{"id":"1c4bd289-bced-48ae-aca1-bf661b0ed325","type":"ColumnDataSource"},"glyph":{"id":"6f2c77d5-f6b0-4692-bf6b-13102eda46e4","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"89427760-b540-4bbf-a885-331b233e8827","type":"Line"},"selection_glyph":null},"id":"8147dad1-dcb9-4b80-a04c-738d4a241efc","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"601c2eee-711e-4c6e-932e-fb6363500af3","type":"BoxAnnotation"},"plot":{"id":"8f79a827-a1ab-4ebb-b397-d6d849719ed5","subtype":"Figure","type":"Plot"}},"id":"3529619b-7ea4-434e-afb7-e1c5348cff75","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"601c2eee-711e-4c6e-932e-fb6363500af3","type":"BoxAnnotation"},{"attributes":{},"id":"63b61bca-548e-4e3c-b7c5-30c974cf42de","type":"BasicTickFormatter"},{"attributes":{},"id":"729319d6-d488-4602-b0de-67cf94940cf4","type":"ToolEvents"},{"attributes":{"below":[{"id":"b4a04c60-774c-44c6-a5e8-a23534138bc3","type":"LinearAxis"}],"left":[{"id":"2ff4d719-62c3-4ccd-bc1f-4c999f3d2971","type":"L ...
#     <div class="bk-root">
#         <div class="plotdiv" id="27589245-6985-4f6f-9a81-3f4a5b3e5361"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("27589245-6985-4f6f-9a81-3f4a5b3e5361");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '27589245-6985-4f6f-9a81-3f4a5b3e5361' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ff5e4edf-96df-43ed-a65f-2073b23628ec":{"roots":{"references":[{"attributes":{},"id":"4761f0a1-745a-4b85-b383-f56e5193e528","type":"BasicTicker"},{"attributes":{"plot":{"id":"6cf5fc5c-b27e-466e-96c7-02a91a4c89db","subtype":"Figure","type":"Plot"},"ticker":{"id":"3feec7e3-9669-4aa2-b81d-72aec50a5fc4","type":"BasicTicker"}},"id":"a36668e8-9e25-48d9-b7b6-be6b169b25d3","type":"Grid"},{"attributes":{},"id":"11e9133b-caf8-4101-919c-00f47bd0998c","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"6cf5fc5c-b27e-466e-96c7-02a91a4c89db","subtype":"Figure","type":"Plot"}},"id":"e7623195-609f-4a9d-97a3-95b78c9552c2","type":"SaveTool"},{"attributes":{},"id":"99e5ed2a-1f95-49e3-bdd0-cc1b93f5282f","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2b288e0b-004c-486e-826e-c6165651cb26","type":"PanTool"},{"id":"27c412a2-8725-40aa-aa87-869ca0429e94","type":"WheelZoomTool"},{"id":"12cc5563-5283-4b0e-9f18-335ba647b4b9","type":"BoxZoomTool"},{"id":"e7623195-609f-4a9d-97a3-95b78c9552c2","type":"SaveTool"},{"id":"0c99aebb-2663-4d10-8838-1ee9a3615310","type":"ResetTool"},{"id":"46df4d3a-b3de-4aaa-9dad-ea1d0aafd218","type":"HelpTool"}]},"id":"ee576c76-6efb-43f9-b2b1-039025479749","type":"Toolbar"},{"attributes":{"axis_label":"epoch","formatter":{"id":"11e9133b-caf8-4101-919c-00f47bd0998c","type":"BasicTickFormatter"},"plot":{"id":"6cf5fc5c-b27e-466e-96c7-02a91a4c89db","subtype":"Figure","type":"Plot"},"ticker":{"id":"3feec7e3-9669-4aa2-b81d-72aec50a5fc4","type":"BasicTicker"}},"id":"9217c3fc-f2de-4415-afb7-0f421d4e521d","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"6cf5fc5c-b27e-466e-96c7-02a91a4c89db","subtype":"Figure","type":"Plot"},"ticker":{"id":"4761f0a1-745a-4b85-b383-f56e5193e528","type":"BasicTicker"}},"id":"c26e9a01-6d0b-43fe-8800-f72a184abe6a","type":"Grid"},{"attributes":{"plot":{"id":"6cf5fc5c-b27e-466e-96c7-02a91a4c89db","subtype":"Figure","type":"Plot"}},"id":"27c412a2-8725-40aa-aa87-869ca0429e94","type":"WheelZoomTool"},{"attributes":{},"id":"3feec7e3-9669-4aa2-b81d-72aec50a5fc4","type":"BasicTicker"},{"attributes":{"below":[{"id":"9217c3fc-f2de-4415-afb7-0f421d4e521d","type":"LinearAxis"}],"left":[{"id":"c959c039-cec7-4208-ad0d-5719f35df31b","type":"LinearAxis"}],"renderers":[{"id":"9217c3fc-f2de-4415-afb7-0f421d4e521d","type":"LinearAxis"},{"id":"a36668e8-9e25-48d9-b7b6-be6b169b25d3","type":"Grid"},{"id":"c959c039-cec7-4208-ad0d-5719f35df31b","type":"LinearAxis"},{"id":"c26e9a01-6d0b-43fe-8800-f72a184abe6a","type":"Grid"},{"id":"468ac5f4-e358-47e5-ae5b-d81201529a11","type":"BoxAnnotation"},{"id":"a45d1009-fca9-462b-9595-56e1cd3db5f1","type":"GlyphRenderer"}],"title":{"id":"d2051e6b-42b0-4536-9e03-fc8a2670d0b2","type":"Title"},"tool_events":{"id":"b04556c1-79fc-4a3f-bec0-b0b907264f79","type":"ToolEvents"},"toolbar":{"id":"ee576c76-6efb-43f9-b2b1-039025479749","type":"Toolbar"},"x_range":{"id":"3836e44b-881d-4128-a14f-ec5f6cdcc4a7","type":"DataRange1d"},"y_range":{"id":"a4a45a4a-265d-41c9-bb9f-961693170657","type":"DataRange1d"}},"id":"6cf5fc5c-b27e-466e-96c7-02a91a4c89db","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"6cf5fc5c-b27e-466e-96c7-02a91a4c89db","subtype":"Figure","type":"Plot"}},"id":"0c99aebb-2663-4d10-8838-1ee9a3615310","type":"ResetTool"},{"attributes":{"callback":null},"id":"a4a45a4a-265d-41c9-bb9f-961693170657","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e229c629-020c-4186-b47c-f8945d74f2ba","type":"Line"},{"attributes":{"overlay":{"id":"468ac5f4-e358-47e5-ae5b-d81201529a11","type":"BoxAnnotation"},"plot":{"id":"6cf5fc5c-b27e-466e-96c7-02a91a4c89db","subtype":"Figure","type":"Plot"}},"id":"12cc5563-5283-4b0e-9f18-335ba647b4b9","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":"train_loss"},"id":"d2051e6b-42b0-4536-9e03-fc8a2670d0b2","type":"Title"},{"attributes":{"axis_label":"l ...
